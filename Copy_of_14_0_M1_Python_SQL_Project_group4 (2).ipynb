# %% [markdown]
# # SQL Project
# You were hired by Ironhack to perform an Analytics Consulting Project entitled: competitive landscape.
#
# Your mission is to create and populate an appropriate database with many coding schools that are our competition, as well as design an suitable queries that answer business questions of interest (to be defined by you)

# %% [markdown]
# **Suggested Steps in the Project:**
#
#
# *   Read this notebook and understand each function. Comment the code appropriately
#
# *   Populate the list of schools with a wider variety of schools (how are you going to get the school ID?)
#
# * Take a look at the obtained dataframes. What dimensions do you have? what keys do you have? how could the different dataframes be connected?
#
# * Go back to the drawing board and try to create an entity relationship diagram for tables available
#
# * Once you have the schemas you want, you will need to:
#   - create the suitable SQL queries to create the tables and populate them
#   - run these queries using the appropriate Python connectors
#
# * Bonus: How will this datamodel be updated in the future? Please write auxiliary functions that test the database for data quality issues. For example: how could you make sure you only include the most recent comments when you re-run the script?
#
#
# # Suggested Deliverables
#
# * 5-6 minute presentation of data model created, decision process and business analysis proposed
#
# * exported .sql file with the final schema
#
# * Supporting python files used to generate all logic
#
# * High level documentation explaining tables designed and focusing on update methods
#
# Crucial hint: check out the following tutorial:
# https://www.dataquest.io/blog/sql-insert-tutorial/

# %%
# you must populate this dict with the schools required -> try talking to the teaching team about this


schools = {   
'ironhack' : 10828,
'udacity' : 11118,
'springboard' : 11035,
'practicum-by-yandex' : 11225,
'brainstation' : 10571,   
}

import re
import pandas as pd
from pandas.io.json import json_normalize
import requests



def get_comments_school(school):
    TAG_RE = re.compile(r'<[^>]+>')
    # defines url to make api call to data -> dynamic with school if you want to scrape competition
    url = "https://www.switchup.org/chimera/v1/school-review-list?mainTemplate=school-review-list&path=%2Fbootcamps%2F" + school + "&isDataTarget=false&page=3&perPage=10000&simpleHtml=true&truncationLength=250"
    #makes get request and converts answer to json
    # url defines the page of all the information, request is made, and information is returned to data variable
    data = requests.get(url).json()
    #converts json to dataframe
    reviews =  pd.DataFrame(data['content']['reviews'])
  
    #aux function to apply regex and remove tags
    def remove_tags(x):
        return TAG_RE.sub('',x)
    reviews['review_body'] = reviews['body'].apply(remove_tags)
    reviews['school'] = school
    return reviews

# %%
# could you write this as a list comprehension? ;)
comments = []

#for school in schools.keys():
#   print(school)
#    comments.append(get_comments_school(school))

comments = [get_comments_school(school) for school in schools.keys()]
comments = pd.concat(comments)
comments
# Out:
#          id            name  anonymous hostProgramName  graduatingYear  \
# 0    283970       Anonymous       True            None          2021.0
# 1    283920  Pekka Tiitinen      False            None          2021.0
# 2    283888       Anonymous       True            None          2021.0
# 3    283886       GASZTOWTT      False            None          2021.0
# 4    283885      Marc Ramos      False            None          2021.0
# ..      ...             ...        ...             ...             ...
# 301  233011       Anonymous      False            None          2015.0
# 302  232993       Anonymous      False            None          2015.0
# 303  232987       Anonymous      False            None          2015.0
# 304  232910       Anonymous      False            None          2015.0
# 305  232524       Anonymous      False            None             NaN
#
#      isAlumni                         jobTitle  \
# 0        True          Innovation and strategy
# 1       False
# 2       False
# 3       False
# 4       False  Full stack Javascript developer
# ..        ...                              ...
# 301      True                             None
# 302      True                             None
# 303      True                             None
# 304      True                             None
# 305     False                             None
#
#                                                tagline  \
# 0    Although there are some things I suggest to im...
# 1                                   Amazing experience
# 2     Overall good experience, a few things to improve
# 3                                              Great !
# 4    Un excellent moyen d'acquérir de bonnes bases ...
# ..                                                 ...
# 301  BrainStation's Product Management course helpe...
# 302  The course offers good continuing education fo...
# 303  The Digital Marketing course is structured so ...
# 304                            Built my first iOS app!
# 305                        Amazing Learning Experience
#
#                                                   body  \
# 0    <span class="truncatable"><p></p><p>Pros - Abh...
# 1    <span class="truncatable"><p></p><p>Very in de...
# 2    <span class="truncatable"><p></p><p>Pluses: - ...
# 3    <span class="truncatable"><p></p><p>I really e...
# 4    <span class="truncatable"><p></p><p>Participer...
# ..                                                 ...
# 301  <span class="truncatable"><p>I took BrainStati...
# 302  <span class="truncatable"><p>The content cover...
# 303  <span class="truncatable"><p>This program has ...
# 304  <span class="truncatable"><p>I am enrolled in ...
# 305  <span class="truncatable"><p>I was registered ...
#
#                                                rawBody  ...   queryDate  \
# 0    <p>Pros - Abhi is really talented as a teacher...  ...  2021-12-07
# 1    <p>Very in depth content and a hands on approa...  ...  2021-12-05
# 2    <p>Pluses: - a lot of things are covered durin...  ...  2021-12-03
# 3    <p>I really enjoyed my whole experience at Iro...  ...  2021-12-03
# 4    <p>Participer &agrave; un bootcamp est une v&e...  ...  2021-12-03
# ..                                                 ...  ...         ...
# 301  I took BrainStation's Product Management cours...  ...  2015-11-10
# 302  The content covered was relevant and interesti...  ...  2015-11-01
# 303  This program has some great insight from peopl...  ...  2015-10-30
# 304  I am enrolled in the Intro to iOS Development ...  ...  2015-10-24
# 305  I was registered for the digital marketing cla...  ...  2015-07-21
#
#                        program             user overallScore  \
# 0     Data Analytics Part-Time  {'image': None}          3.7
# 1    Web Development Part-Time  {'image': None}          4.7
# 2     Web Development Bootcamp  {'image': None}          3.7
# 3     Web Development Bootcamp  {'image': None}          3.7
# 4     Web Development Bootcamp  {'image': None}          4.3
# ..                         ...              ...          ...
# 301         Product Management  {'image': None}          5.0
# 302          Digital Marketing  {'image': None}          3.0
# 303          Digital Marketing  {'image': None}          4.0
# 304            iOS Development  {'image': None}          5.0
# 305          Digital Marketing  {'image': None}          4.0
#
#                                               comments overall curriculum  \
# 0                                                   []     4.0        4.0
# 1                                                   []     5.0        5.0
# 2                                                   []     4.0        4.0
# 3                                                   []     4.0        4.0
# 4                                                   []     5.0        4.0
# ..                                                 ...     ...        ...
# 301                                                 []     5.0        NaN
# 302  [{'name': 'contact@brainstation.io', 'email': ...     3.0        NaN
# 303                                                 []     4.0        NaN
# 304                                                 []     5.0        NaN
# 305                                                 []     5.0        5.0
#
#     jobSupport                                        review_body  \
# 0          3.0  Pros - Abhi is really talented as a teacher. H...
# 1          4.0  Very in depth content and a hands on approach ...
# 2          3.0  Pluses: - a lot of things are covered during 9...
# 3          3.0  I really enjoyed my whole experience at Ironha...
# 4          4.0  Participer à un bootcamp est une véritable ave...
# ..         ...                                                ...
# 301        NaN  I took BrainStation's Product Management cours...
# 302        NaN  The content covered was relevant and interesti...
# 303        NaN  This program has some great insight from peopl...
# 304        NaN  I am enrolled in the Intro to iOS Development ...
# 305        2.0  I was registered for the digital marketing cla...
#
#            school
# 0        ironhack
# 1        ironhack
# 2        ironhack
# 3        ironhack
# 4        ironhack
# ..            ...
# 301  brainstation
# 302  brainstation
# 303  brainstation
# 304  brainstation
# 305  brainstation
#
# [3984 rows x 21 columns]

# %%
comments["school"].unique()
# Out:
# array(['ironhack', 'udacity', 'springboard', 'practicum-by-yandex',
#        'brainstation'], dtype=object)

# %%
from pandas.io.json import json_normalize

def get_school_info(school, school_id):
    url = 'https://www.switchup.org/chimera/v1/bootcamp-data?mainTemplate=bootcamp-data%2Fdescription&path=%2Fbootcamps%2F'+ str(school) + '&isDataTarget=false&bootcampId='+ str(school_id) + '&logoTag=logo&truncationLength=250&readMoreOmission=...&readMoreText=Read%20More&readLessText=Read%20Less'

    data = requests.get(url).json()

    data.keys()

    courses = data['content']['courses']
    courses_df = pd.DataFrame(courses, columns= ['courses'])

    locations = data['content']['locations']
    locations_df = json_normalize(locations)

    badges_df = pd.DataFrame(data['content']['meritBadges'])
    
    website = data['content']['webaddr']
    description = data['content']['description']
    logoUrl = data['content']['logoUrl']
    school_df = pd.DataFrame([website,description,logoUrl]).T
    school_df.columns =  ['website','description','LogoUrl']

    locations_df['school'] = school
    courses_df['school'] = school
    badges_df['school'] = school
    school_df['school'] = school
    

    locations_df['school_id'] = school_id
    courses_df['school_id'] = school_id
    badges_df['school_id'] = school_id
    school_df['school_id'] = school_id

    return locations_df, courses_df, badges_df, school_df

locations_list = []
courses_list = []
badges_list = []
schools_list = []

for school, id in schools.items():
    print(school)
    a,b,c,d = get_school_info(school,id)
    
    locations_list.append(a)
    courses_list.append(b)
    badges_list.append(c)
    schools_list.append(d)
# Out:
# ironhack
# <ipython-input-161-7111c633f1e2>:14: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   locations_df = json_normalize(locations)
# udacity
# springboard
# practicum-by-yandex
# brainstation

# %%
locations_list
# Out:
# [      id               description  country.id   country.name country.abbrev  \
#  0  15901           Berlin, Germany        57.0        Germany             DE
#  1  16022       Mexico City, Mexico        29.0         Mexico             MX
#  2  16086    Amsterdam, Netherlands        59.0    Netherlands             NL
#  3  16088         Sao Paulo, Brazil        42.0         Brazil             BR
#  4  16109             Paris, France        38.0         France             FR
#  5  16375  Miami, FL, United States         1.0  United States             US
#  6  16376             Madrid, Spain        12.0          Spain             ES
#  7  16377          Barcelona, Spain        12.0          Spain             ES
#  8  16709          Lisbon, Portugal        28.0       Portugal             PT
#  9  17233                    Online         NaN            NaN            NaN
#
#     city.id    city.name city.keyword  state.id state.name state.abbrev  \
#  0  31156.0       Berlin       berlin       NaN        NaN          NaN
#  1  31175.0  Mexico City  mexico-city       NaN        NaN          NaN
#  2  31168.0    Amsterdam    amsterdam       NaN        NaN          NaN
#  3  31121.0    Sao Paulo    sao-paulo       NaN        NaN          NaN
#  4  31136.0        Paris        paris       NaN        NaN          NaN
#  5     31.0        Miami        miami      11.0    Florida           FL
#  6  31052.0       Madrid       madrid       NaN        NaN          NaN
#  7  31170.0    Barcelona    barcelona       NaN        NaN          NaN
#  8  31075.0       Lisbon       lisbon       NaN        NaN          NaN
#  9      NaN          NaN          NaN       1.0     Online       Online
#
#    state.keyword    school  school_id
#  0           NaN  ironhack      10828
#  1           NaN  ironhack      10828
#  2           NaN  ironhack      10828
#  3           NaN  ironhack      10828
#  4           NaN  ironhack      10828
#  5       florida  ironhack      10828
#  6           NaN  ironhack      10828
#  7           NaN  ironhack      10828
#  8           NaN  ironhack      10828
#  9        online  ironhack      10828  ,
#        id description  state.id state.name state.abbrev state.keyword   school  \
#  0  15807      Online         1     Online       Online        online  udacity
#
#     school_id
#  0      11118  ,
#        id description  state.id state.name state.abbrev state.keyword  \
#  0  16013      Online         1     Online       Online        online
#
#          school  school_id
#  0  springboard      11035  ,
#        id description  state.id state.name state.abbrev state.keyword  \
#  0  17154      Online         1     Online       Online        online
#
#                  school  school_id
#  0  practicum-by-yandex      11225  ,
#        id        description  country.id    country.name country.abbrev  \
#  0  15935  New York City, NY         1.0   United States             US
#  1  15985    Toronto, Canada         2.0          Canada             CA
#  2  16010  Vancouver, Canada         2.0          Canada             CA
#  3  16909         Boston, MA         1.0   United States             US
#  4  16910        Chicago, IL         1.0   United States             US
#  5  16940             Online         NaN             NaN            NaN
#  6  17706          Miami, FL         1.0   United States             US
#  7  17731         London, UK        11.0  United Kingdom             GB
#
#     state.id        state.name state.abbrev  state.keyword  city.id  city.name  \
#  0      34.0          New York           NY       new-york   1507.0        NYC
#  1       NaN               NaN          NaN            NaN   1547.0    Toronto
#  2      71.0  British Columbia           BC                 31138.0  Vancouver
#  3      23.0     Massachusetts           MA  massachusetts     47.0     Boston
#  4      15.0          Illinois           IL       illinois     39.0    Chicago
#  5       1.0            Online       Online         online      NaN        NaN
#  6      11.0           Florida           FL        florida     31.0      Miami
#  7       NaN               NaN          NaN            NaN  31176.0     London
#
#      city.keyword        school  school_id
#  0  new-york-city  brainstation      10571
#  1        toronto  brainstation      10571
#  2      vancouver  brainstation      10571
#  3         boston  brainstation      10571
#  4        chicago  brainstation      10571
#  5            NaN  brainstation      10571
#  6          miami  brainstation      10571
#  7         london  brainstation      10571  ]

# %%
locations = pd.concat(locations_list)
locations
# Out:
#       id               description  country.id    country.name country.abbrev  \
# 0  15901           Berlin, Germany        57.0         Germany             DE
# 1  16022       Mexico City, Mexico        29.0          Mexico             MX
# 2  16086    Amsterdam, Netherlands        59.0     Netherlands             NL
# 3  16088         Sao Paulo, Brazil        42.0          Brazil             BR
# 4  16109             Paris, France        38.0          France             FR
# 5  16375  Miami, FL, United States         1.0   United States             US
# 6  16376             Madrid, Spain        12.0           Spain             ES
# 7  16377          Barcelona, Spain        12.0           Spain             ES
# 8  16709          Lisbon, Portugal        28.0        Portugal             PT
# 9  17233                    Online         NaN             NaN            NaN
# 0  15807                    Online         NaN             NaN            NaN
# 0  16013                    Online         NaN             NaN            NaN
# 0  17154                    Online         NaN             NaN            NaN
# 0  15935         New York City, NY         1.0   United States             US
# 1  15985           Toronto, Canada         2.0          Canada             CA
# 2  16010         Vancouver, Canada         2.0          Canada             CA
# 3  16909                Boston, MA         1.0   United States             US
# 4  16910               Chicago, IL         1.0   United States             US
# 5  16940                    Online         NaN             NaN            NaN
# 6  17706                 Miami, FL         1.0   United States             US
# 7  17731                London, UK        11.0  United Kingdom             GB
#
#    city.id    city.name   city.keyword  state.id        state.name  \
# 0  31156.0       Berlin         berlin       NaN               NaN
# 1  31175.0  Mexico City    mexico-city       NaN               NaN
# 2  31168.0    Amsterdam      amsterdam       NaN               NaN
# 3  31121.0    Sao Paulo      sao-paulo       NaN               NaN
# 4  31136.0        Paris          paris       NaN               NaN
# 5     31.0        Miami          miami      11.0           Florida
# 6  31052.0       Madrid         madrid       NaN               NaN
# 7  31170.0    Barcelona      barcelona       NaN               NaN
# 8  31075.0       Lisbon         lisbon       NaN               NaN
# 9      NaN          NaN            NaN       1.0            Online
# 0      NaN          NaN            NaN       1.0            Online
# 0      NaN          NaN            NaN       1.0            Online
# 0      NaN          NaN            NaN       1.0            Online
# 0   1507.0          NYC  new-york-city      34.0          New York
# 1   1547.0      Toronto        toronto       NaN               NaN
# 2  31138.0    Vancouver      vancouver      71.0  British Columbia
# 3     47.0       Boston         boston      23.0     Massachusetts
# 4     39.0      Chicago        chicago      15.0          Illinois
# 5      NaN          NaN            NaN       1.0            Online
# 6     31.0        Miami          miami      11.0           Florida
# 7  31176.0       London         london       NaN               NaN
#
#   state.abbrev  state.keyword               school  school_id
# 0          NaN            NaN             ironhack      10828
# 1          NaN            NaN             ironhack      10828
# 2          NaN            NaN             ironhack      10828
# 3          NaN            NaN             ironhack      10828
# 4          NaN            NaN             ironhack      10828
# 5           FL        florida             ironhack      10828
# 6          NaN            NaN             ironhack      10828
# 7          NaN            NaN             ironhack      10828
# 8          NaN            NaN             ironhack      10828
# 9       Online         online             ironhack      10828
# 0       Online         online              udacity      11118
# 0       Online         online          springboard      11035
# 0       Online         online  practicum-by-yandex      11225
# 0           NY       new-york         brainstation      10571
# 1          NaN            NaN         brainstation      10571
# 2           BC                        brainstation      10571
# 3           MA  massachusetts         brainstation      10571
# 4           IL       illinois         brainstation      10571
# 5       Online         online         brainstation      10571
# 6           FL        florida         brainstation      10571
# 7          NaN            NaN         brainstation      10571

# %%
courses = pd.concat(courses_list)
courses["courses"].unique()
# Out:
# array(['Cyber Security Bootcamp', 'Cybersecurity Part-Time',
#        'Data Analytics Bootcamp', 'Data Analytics Part-Time',
#        'UX/UI Design Bootcamp', 'UX/UI Design Part-Time',
#        'Web Development Bootcamp', 'Web Development Part-Time',
#        'AI Programming with Python', 'Al Product Manager',
#        'Android Basics', 'Android Developer', 'Artificial Intelligence',
#        'Artificial Intelligence for Trading', 'Blockchain Developer',
#        'Business Analytics', 'C++', 'Cloud Dev Ops Engineer',
#        'Cloud Developer', 'Computer Vision', 'Data Analyst',
#        'Data Engineer', 'Data Structures and Algorithms',
#        'Data Visualization', 'Deep Learning',
#        'Deep Reinforcement Learning', 'Digital Marketing',
#        'Front End Web Developer', 'Full Stack Web Developer',
#        'Introduction to Machine Learning', 'Introduction to Programming',
#        'iOS Developer', 'Java Developer', 'Machine Learning Engineer',
#        'Marketing Analytics', 'Natural Language Processing',
#        'Predictive Analytics for Business', 'React',
#        'Robotics Software Engineer', 'Self-Driving Car Engineer',
#        'UX Designer', 'Cyber Security Career Track',
#        'Data Analytics Career Track', 'Data Engineering Career Track',
#        'Data Science Career Track', 'Data Science Career Track Prep',
#        'Introduction to Data Analytics', 'Introduction to Design',
#        'Software Engineering Career Track',
#        'Software Engineering Career Track Prep Course',
#        'UI/UX Design Career Track', 'UX Career Track', 'Data Scientist',
#        'Web Developer', 'Cybersecurity Certificate Course',
#        'Data Analytics Certificate Course',
#        'Data Science Certificate Course', 'Design Thinking',
#        'Digital Leadership & Innovation Certificate',
#        'iOS Development Certificate Course',
#        'Machine Learning Certificate Course',
#        'Product Management Certificate Course', 'Python Programming',
#        'Search Engine Marketing Certificate Course',
#        'Social Media Marketing',
#        'User Experience Design Certificate Course',
#        'User Interface Design Certificate Course',
#        'Web Development Certificate Course',
#        'Data Science Diploma Program',
#        'Digital Marketing Diploma Program',
#        'User Experience Design Diploma Program',
#        'Web Development Diploma Program'], dtype=object)

# %%
badges = pd.concat(badges_list)
badges.head()
# Out:
#                 name            keyword  \
# 0   Available Online   available_online
# 1  Verified Outcomes  verified_outcomes
# 2   Flexible Classes   flexible_classes
# 0   Available Online   available_online
# 1   Flexible Classes   flexible_classes
#
#                                          description    school  school_id
# 0          <p>School offers fully online courses</p>  ironhack      10828
# 1  <p>School publishes a third-party verified out...  ironhack      10828
# 2  <p>School offers part-time and evening classes...  ironhack      10828
# 0          <p>School offers fully online courses</p>   udacity      11118
# 1  <p>School offers part-time and evening classes...   udacity      11118

# %%
# any data cleaning still missing here? take a look at the description
schools = pd.concat(schools_list)
schools.head()
# Out:
#                                              website  \
# 0                                www.ironhack.com/en
# 0  www.udacity.com/?utm_source=switchup&utm_mediu...
# 0  www.springboard.com/?utm_source=switchup&utm_m...
# 0  practicum.yandex.com/?utm_source=referral&utm_...
# 0                                    brainstation.io
#
#                                          description  \
# 0  <span class="truncatable"><p>Ironhack is a glo...
# 0  <span class="truncatable"><p>Udacity is a glob...
# 0  <span class="truncatable"><p>Springboard is an...
# 0  <span class="truncatable"><p>Created by engine...
# 0  <span class="truncatable"><p>BrainStation is t...
#
#                                              LogoUrl               school  \
# 0  https://d92mrp7hetgfk.cloudfront.net/images/si...             ironhack
# 0  https://d92mrp7hetgfk.cloudfront.net/images/si...              udacity
# 0  https://d92mrp7hetgfk.cloudfront.net/images/si...          springboard
# 0  https://d92mrp7hetgfk.cloudfront.net/images/si...  practicum-by-yandex
# 0  https://d92mrp7hetgfk.cloudfront.net/images/si...         brainstation
#
#    school_id
# 0      10828
# 0      11118
# 0      11035
# 0      11225
# 0      10571

# %%
cleaned_schools = locations[['school_id','school']]
cleaned_schools.columns = ['schools_id','name']
cleaned_schools = cleaned_schools.drop_duplicates(subset=['schools_id'])
cleaned_schools
# Out:
#    schools_id                 name
# 0       10828             ironhack
# 0       11118              udacity
# 0       11035          springboard
# 0       11225  practicum-by-yandex
# 0       10571         brainstation

# %%
badges
# Out:
#                 name            keyword  \
# 0   Available Online   available_online
# 1  Verified Outcomes  verified_outcomes
# 2   Flexible Classes   flexible_classes
# 0   Available Online   available_online
# 1   Flexible Classes   flexible_classes
# 0   Available Online   available_online
# 1   Flexible Classes   flexible_classes
# 2      Job Guarantee      job_guarantee
# 0   Available Online   available_online
# 1      Job Guarantee      job_guarantee
# 0   Available Online   available_online
# 1   Flexible Classes   flexible_classes
#
#                                          description               school  \
# 0          <p>School offers fully online courses</p>             ironhack
# 1  <p>School publishes a third-party verified out...             ironhack
# 2  <p>School offers part-time and evening classes...             ironhack
# 0          <p>School offers fully online courses</p>              udacity
# 1  <p>School offers part-time and evening classes...              udacity
# 0          <p>School offers fully online courses</p>          springboard
# 1  <p>School offers part-time and evening classes...          springboard
# 2             <p>School guarantees job placement</p>          springboard
# 0          <p>School offers fully online courses</p>  practicum-by-yandex
# 1             <p>School guarantees job placement</p>  practicum-by-yandex
# 0          <p>School offers fully online courses</p>         brainstation
# 1  <p>School offers part-time and evening classes...         brainstation
#
#    school_id
# 0      10828
# 1      10828
# 2      10828
# 0      11118
# 1      11118
# 0      11035
# 1      11035
# 2      11035
# 0      11225
# 1      11225
# 0      10571
# 1      10571

# %%
df2 = cleaned_schools.rename(columns={'name':'school'})
cleaned_comments = comments.merge(df2, how='inner', on='school')
display(cleaned_comments.columns)
list_of_drops = ['anonymous', 'hostProgramName', 'graduatingYear', 'tagline', 'body', 'rawBody', 'createdAt', 'user', 'comments', 'review_body','school']
cleaned_comments.drop(list_of_drops, inplace=True,axis=1)
cleaned_comments = cleaned_comments.fillna("0")
cleaned_comments['overall'] = cleaned_comments['overall'].apply(lambda x : float(x))
cleaned_comments['overallScore'] = cleaned_comments['overallScore'].apply(lambda x : float(x))
cleaned_comments['curriculum'] = cleaned_comments['curriculum'].apply(lambda x : float(x))
cleaned_comments['jobSupport'] = cleaned_comments['jobSupport'].apply(lambda x : float(x))
# Out:
# Index(['id', 'name', 'anonymous', 'hostProgramName', 'graduatingYear',
#        'isAlumni', 'jobTitle', 'tagline', 'body', 'rawBody', 'createdAt',
#        'queryDate', 'program', 'user', 'overallScore', 'comments', 'overall',
#        'curriculum', 'jobSupport', 'review_body', 'school', 'schools_id'],
#       dtype='object')

# %%
cleaned_comments
# Out:
#           id            name  isAlumni                         jobTitle  \
# 0     283970       Anonymous      True          Innovation and strategy
# 1     283920  Pekka Tiitinen     False
# 2     283888       Anonymous     False
# 3     283886       GASZTOWTT     False
# 4     283885      Marc Ramos     False  Full stack Javascript developer
# ...      ...             ...       ...                              ...
# 3979  233011       Anonymous      True                                0
# 3980  232993       Anonymous      True                                0
# 3981  232987       Anonymous      True                                0
# 3982  232910       Anonymous      True                                0
# 3983  232524       Anonymous     False                                0
#
#        queryDate                    program  overallScore  overall  \
# 0     2021-12-07   Data Analytics Part-Time           3.7      4.0
# 1     2021-12-05  Web Development Part-Time           4.7      5.0
# 2     2021-12-03   Web Development Bootcamp           3.7      4.0
# 3     2021-12-03   Web Development Bootcamp           3.7      4.0
# 4     2021-12-03   Web Development Bootcamp           4.3      5.0
# ...          ...                        ...           ...      ...
# 3979  2015-11-10         Product Management           5.0      5.0
# 3980  2015-11-01          Digital Marketing           3.0      3.0
# 3981  2015-10-30          Digital Marketing           4.0      4.0
# 3982  2015-10-24            iOS Development           5.0      5.0
# 3983  2015-07-21          Digital Marketing           4.0      5.0
#
#       curriculum  jobSupport  schools_id
# 0            4.0         3.0       10828
# 1            5.0         4.0       10828
# 2            4.0         3.0       10828
# 3            4.0         3.0       10828
# 4            4.0         4.0       10828
# ...          ...         ...         ...
# 3979         0.0         0.0       10571
# 3980         0.0         0.0       10571
# 3981         0.0         0.0       10571
# 3982         0.0         0.0       10571
# 3983         5.0         2.0       10571
#
# [3984 rows x 11 columns]

# %%
cleaned_locations = locations.copy()
list_to_drop = ['description','country.id','country.abbrev','city.id','city.keyword','state.id','state.name','state.abbrev','state.keyword']
cleaned_locations.drop(list_to_drop,inplace=True,axis=1,)
cleaned_locations.rename(columns = {'id':'location_id','country.name':'country','city.name':'city'}, inplace = True)
cleaned_locations = cleaned_locations.fillna(value = "Online")

# %%
badges_raw = pd.concat(badges_list)
badges_raw = badges_raw.drop_duplicates(subset=['name'])
badges_raw
# Out:
#                 name            keyword  \
# 0   Available Online   available_online
# 1  Verified Outcomes  verified_outcomes
# 2   Flexible Classes   flexible_classes
# 2      Job Guarantee      job_guarantee
#
#                                          description       school  school_id
# 0          <p>School offers fully online courses</p>     ironhack      10828
# 1  <p>School publishes a third-party verified out...     ironhack      10828
# 2  <p>School offers part-time and evening classes...     ironhack      10828
# 2             <p>School guarantees job placement</p>  springboard      11035

# %%
def badges_m(row):
    if row == 'Available Online':
        return 1
    elif row == 'Verified Outcomes':
        return 2
    elif row == 'Flexible Classes':
        return 3
    elif row == 'Job Guarantee':
        return 4

# %%
badges_raw.insert(0,'badges_id',(badges_raw['name'].apply(badges_m)))

# %%
badges = badges_raw

# %%
badges.columns = ['badges_id','name','keyword','description','school','school_id']

# %%
clean_badges = badges[['badges_id','name']]

# %%
clean_badges
# Out:
#    badges_id               name
# 0          1   Available Online
# 1          2  Verified Outcomes
# 2          3   Flexible Classes
# 2          4      Job Guarantee

# %%
subdf = pd.concat(badges_list)
badges_for_schools = subdf[['name','school_id']]
badges_for_schools = badges_for_schools.merge(clean_badges,how='inner',on='name')
badges_for_schools.insert(0,'school_badges_id',(range(1,13)))
badges_for_schools = badges_for_schools[['school_badges_id','school_id','badges_id']]

# %%
badges_for_schools
# Out:
#     school_badges_id  school_id  badges_id
# 0                  1      10828          1
# 1                  2      11118          1
# 2                  3      11035          1
# 3                  4      11225          1
# 4                  5      10571          1
# 5                  6      10828          2
# 6                  7      10828          3
# 7                  8      11118          3
# 8                  9      11035          3
# 9                 10      10571          3
# 10                11      11035          4
# 11                12      11225          4

# %%
display(badges_for_schools)
display(cleaned_comments)
display(cleaned_schools)
display(cleaned_locations)
display(courses)
# Out:
#     school_badges_id  school_id  badges_id
# 0                  1      10828          1
# 1                  2      11118          1
# 2                  3      11035          1
# 3                  4      11225          1
# 4                  5      10571          1
# 5                  6      10828          2
# 6                  7      10828          3
# 7                  8      11118          3
# 8                  9      11035          3
# 9                 10      10571          3
# 10                11      11035          4
# 11                12      11225          4
#           id            name  isAlumni                         jobTitle  \
# 0     283970       Anonymous      True          Innovation and strategy
# 1     283920  Pekka Tiitinen     False
# 2     283888       Anonymous     False
# 3     283886       GASZTOWTT     False
# 4     283885      Marc Ramos     False  Full stack Javascript developer
# ...      ...             ...       ...                              ...
# 3979  233011       Anonymous      True                                0
# 3980  232993       Anonymous      True                                0
# 3981  232987       Anonymous      True                                0
# 3982  232910       Anonymous      True                                0
# 3983  232524       Anonymous     False                                0
#
#        queryDate                    program  overallScore  overall  \
# 0     2021-12-07   Data Analytics Part-Time           3.7      4.0
# 1     2021-12-05  Web Development Part-Time           4.7      5.0
# 2     2021-12-03   Web Development Bootcamp           3.7      4.0
# 3     2021-12-03   Web Development Bootcamp           3.7      4.0
# 4     2021-12-03   Web Development Bootcamp           4.3      5.0
# ...          ...                        ...           ...      ...
# 3979  2015-11-10         Product Management           5.0      5.0
# 3980  2015-11-01          Digital Marketing           3.0      3.0
# 3981  2015-10-30          Digital Marketing           4.0      4.0
# 3982  2015-10-24            iOS Development           5.0      5.0
# 3983  2015-07-21          Digital Marketing           4.0      5.0
#
#       curriculum  jobSupport  schools_id
# 0            4.0         3.0       10828
# 1            5.0         4.0       10828
# 2            4.0         3.0       10828
# 3            4.0         3.0       10828
# 4            4.0         4.0       10828
# ...          ...         ...         ...
# 3979         0.0         0.0       10571
# 3980         0.0         0.0       10571
# 3981         0.0         0.0       10571
# 3982         0.0         0.0       10571
# 3983         5.0         2.0       10571
#
# [3984 rows x 11 columns]
#    schools_id                 name
# 0       10828             ironhack
# 0       11118              udacity
# 0       11035          springboard
# 0       11225  practicum-by-yandex
# 0       10571         brainstation
#    location_id         country         city               school  school_id
# 0        15901         Germany       Berlin             ironhack      10828
# 1        16022          Mexico  Mexico City             ironhack      10828
# 2        16086     Netherlands    Amsterdam             ironhack      10828
# 3        16088          Brazil    Sao Paulo             ironhack      10828
# 4        16109          France        Paris             ironhack      10828
# 5        16375   United States        Miami             ironhack      10828
# 6        16376           Spain       Madrid             ironhack      10828
# 7        16377           Spain    Barcelona             ironhack      10828
# 8        16709        Portugal       Lisbon             ironhack      10828
# 9        17233          Online       Online             ironhack      10828
# 0        15807          Online       Online              udacity      11118
# 0        16013          Online       Online          springboard      11035
# 0        17154          Online       Online  practicum-by-yandex      11225
# 0        15935   United States          NYC         brainstation      10571
# 1        15985          Canada      Toronto         brainstation      10571
# 2        16010          Canada    Vancouver         brainstation      10571
# 3        16909   United States       Boston         brainstation      10571
# 4        16910   United States      Chicago         brainstation      10571
# 5        16940          Online       Online         brainstation      10571
# 6        17706   United States        Miami         brainstation      10571
# 7        17731  United Kingdom       London         brainstation      10571
#                                    courses        school  school_id
# 0                  Cyber Security Bootcamp      ironhack      10828
# 1                  Cybersecurity Part-Time      ironhack      10828
# 2                  Data Analytics Bootcamp      ironhack      10828
# 3                 Data Analytics Part-Time      ironhack      10828
# 4                    UX/UI Design Bootcamp      ironhack      10828
# ..                                     ...           ...        ...
# 14      Web Development Certificate Course  brainstation      10571
# 15            Data Science Diploma Program  brainstation      10571
# 16       Digital Marketing Diploma Program  brainstation      10571
# 17  User Experience Design Diploma Program  brainstation      10571
# 18         Web Development Diploma Program  brainstation      10571
#
# [74 rows x 3 columns]

# %%
lst = list()
for i in courses['courses']:
    if i.find('Data') != -1:
        lst.append('Data')
    else:
        lst.append(i)
courses['courses'] = pd.Series(lst)
courses
# Out:
#                     courses        school  school_id
# 0   Cyber Security Bootcamp      ironhack      10828
# 1   Cybersecurity Part-Time      ironhack      10828
# 2                      Data      ironhack      10828
# 3                      Data      ironhack      10828
# 4     UX/UI Design Bootcamp      ironhack      10828
# ..                      ...           ...        ...
# 14     Blockchain Developer  brainstation      10571
# 15       Business Analytics  brainstation      10571
# 16                      C++  brainstation      10571
# 17   Cloud Dev Ops Engineer  brainstation      10571
# 18          Cloud Developer  brainstation      10571
#
# [74 rows x 3 columns]

# %%
word_list=['Data', 'Analytics']
def change(row):
    for element in word_list:
        if element in row:
            return 'DA'
        else:
            return row





cleaned_comments['program']=cleaned_comments['program'].apply(change)

# %%
cleaned_comments['jobTitle'].unique()
# Out:
# array(['Innovation and strategy', '', 'Full stack Javascript developer',
#        'UX/UI Designer', 'UX UI Designer', 'Full-Stack developer',
#        'Web developer', 'Product Designer', 'Full Stack Developer',
#        'full stack developer', 'UXUI Designer', 'Frontend Developer',
#        'Product designer', 'ux ui designer', 'web dev fullstack',
#        'Junior Data Analyst', 'Data Analyst', 'Web Developer',
#        'Junior Web Dev', 'UX/UI designer', 'Growth engineer/marketer',
#        'Senior Associate', 'Data Analytics', 'Software Engineer',
#        'Ux ui designer', 'ux/ui product designer',
#        'Fullstack web developer', 'Full stack developer',
#        'Development Operations Engineer', 'Web Dev', 'UX Designer',
#        'Full-Stack Web Developer', 'Student',
#        'Head of Sales / Fullstack developer',
#        'Power BI Junior Consultant', 'UX/UI Design',
#        'Full Stack Web Developer', 'unemployed', 'frontend developer',
#        'UX designer', 'Web Developer junior', 'web dev', 'web developper',
#        'Unemployed', 'UI Designer', 'CoFounder of Botcave SAS',
#        'Data  analyst', 'Fullstack Web Developer',
#        'Learning and Development Specialist', 'Ux/Ui Designer',
#        'Junior Front End Developer', 'Junior Software Developer',
#        'React Developer', 'UX-UI designer', 'Full stack web developer',
#        'Software Developer Jr., Data Analyst Jr., Structural engineering PhD.',
#        'Graphic Designer', 'UX-designer', 'Front-End Developer',
#        'Insights Project Manager', 'Designer',
#        'full stack web developer/teacher', 'Growth',
#        'Full-stack Web Developer', 'Full-stack web-developer',
#        'Junior UI Developer', 'Product Manager', 'Full-stack developer',
#        'Front End Developer', 'Data Analytics Student',
#        'Software Developer', 'Web Dev TA', 'Junior data analyst',
#        'Finance Analyst', 'UX Designer/UX Writer', 'Data analyst',
#        'Engenheira de dados', 'Senior software engineer', 'Front End Dev',
#        'Full stack Developer', 'Data Engineer', 'JavaScript Developer',
#        'UX UI designer', 'ux/ui designer', 'Junior Web Developer',
#        'Head of design', 'Data Science and Advanced Analytics Manager',
#        'Developer', 'Program Manager', 'Teacher Assistant', '0',
#        'Web Dev.  Full Stack', 'Full Stack web developer', 'Software Dev',
#        'Web dev Full Stack', 'Jr Fullstack web developer',
#        'Jr Full Stack Developer', 'Web Developer Full Stack',
#        'Developer Trainee', 'Junior Product Designer',
#        'Junior Webdeveloper', 'Interactive Developer', 'Web-dev',
#        'web dev student', 'Junior Full Stack Web Dev',
#        'Full Stack Developer Junior', 'Full stack web dev',
#        'Front-End Web Developer', 'UX DESIGNER', 'Web Development ',
#        'Computer software engineer', 'Support engineer',
#        'UX - UI Designer', 'Web dev', 'Software Engineer ',
#        'UX/UI and graphic designer', 'UX UI Design',
#        'Front end web developer',
#        'Fullstack web developer &amp; Teach assistant',
#        'UX UI Designer Junior',
#        'Freelancing UX/UI Designer &amp; Travel agent', 'Web Dev.',
#        'IT Consultant', 'UX/UI', 'UX &amp; UI Designer',
#        'Estudiante de desarrollo web', 'full stack web developer',
#        'Full Stack Dev', 'Jr Full Stack developer',
#        'Junior Fullstack Developer', 'Junior Full Stack Developer',
#        'Full-Stack Developer', 'Therapist', 'Web Content Analyst',
#        'Javascript Engineer', 'UX DEsigner', 'co-founder at Leemur',
#        'Ux/UI Designer', 'Junior backend developer', 'Creative Designer',
#        'UX/UI Design Teacher Assistant', 'Web Development',
#        'RPA Developer', 'Associate Software Engineer', 'Web development',
#        'Customer Success Associate at Nuvola', 'General Manager',
#        'Freelance Full Stack Web Developer', 'TPT Business Development',
#        'TA at Ironhack', 'UX/UI Designer ', 'Ironhack Graduate',
#        'Creative Team Lead', 'Association Web Engineer',
#        'Creative Manager', 'Creative Development Manager',
#        'Teacher Assistant at Ironhack', 'Full Stack Web Developer ',
#        'Interaction Designer', 'Front-end developer',
#        'Full mern stack student', 'Full-stack Developer',
#        'Teacher Assistant @ Ironhack Paris',
#        'UX Designer and Full Stack Developer', 'Fullstack developer',
#        'Product Owner', 'Teaching Assistant', 'Partner @Orion',
#        'Analytics Consultant', 'Full Stack', 'Ux Ui Designer',
#        'Front-End Developer Junior', 'Associate Front End Web Developer',
#        'UX/UI designer M.A Visual and Performing Arts', 'UXUI designer',
#        'Former UX/UI Student', 'student', 'UX/UI design',
#        'Technical Recruiter ', 'Industrial/ Graphic and UX/UI Designer ',
#        'Owner', 'Full Stack Developer || Digital Analyst',
#        'Web Designer &amp; Developer', 'Director of Ecommerce Operations',
#        'Programmer Analyst', 'Programmer', 'Project Manager',
#        'Software Architect', 'UX Researcher',
#        'Frontend Developer at Cabify', 'Desarrollador Front-end',
#        'Designer and Front-End Developer', 'UX ', 'UX&amp;UI Designer',
#        'UX/UI Designer &amp; Front End Developer',
#        'Architect &amp; UX/UI Designer', 'UX7UI',
#        'Engineer L1 - Full Stack Web Developer', 'Junior .Net Developer',
#        'Solution Architect', 'Founder', 'Product Designer ',
#        'TA Ironhack', 'FullStack Developer', 'Jr Web Developer',
#        'Product Designer &amp; Full Stack Developer',
#        'Diseñador de Producto',
#        'Full Stack Web Developer - JavaScript, MongoDB, Express, Angular 4, Node.js',
#        'Marketing &amp; UX specialist', 'OUwebs Founder',
#        'Business School Student', 'Javascript Developer',
#        'Founder Billin', 'UX/UI DESIGNER',
#        'Junior Web Application Developer', 'service designer',
#        'UX/ UI Designer', 'Frontend developer ', 'Experience Designer',
#        'Web Applications Developer', 'Junior Associate Web Developer',
#        'Front-End Engineer', 'Front End Web Developer',
#        'Software Development Engineer',
#        'Front End Developer at TransUnion', 'HIT Consultant ',
#        'Frontend Developer &amp; UXUI', 'Staff Software Engineer',
#        'Assistant teacher', 'IT Director', 'Lead Software Engineer',
#        'UCLA Student', 'Front-end Developer', 'COO at Tender.co',
#        'IT Trainer', 'UX / UI &amp; Front End Designer',
#        'JavaScript Engineer', 'Java Full-Stack Developer',
#        'UX / UI Designer', 'Product Developer', 'Jr UX Architec',
#        'Fullstack Developer', 'Digital Product Designer', 'LEAD UX/UI',
#        'Contract Web Developer', 'Web Application Developer',
#        'IB Analyst', 'Full Stack Web Developper', 'Lead UX at Loycus',
#        'Junior JavaScript Application Developer', 'Backend Developer',
#        'Digital Analyst', 'Founder, Donkies Technologies',
#        'Digital Product Manager', 'IT Recruiter', 'Jr. Developer',
#        'Front End Engineer', 'Sr. Digital Account Manager',
#        'iOS Developer', 'Entrepreneur',
#        'Founder, RoR Developer @ Decorissimo.es', 'Pharmacist',
#        'Digital marketing', 'Systems Administrator', 'Digital Marketing',
#        'product marketing manager', 'JavaScript developer',
#        'social media specialist', 'physiotherapist', 'Digital marketer',
#        'master student', 'Full-time student',
#        'Senior Digital Marketer / Product Manager', 'front end developer',
#        'CEO at Mecha Solar', 'Aerospace engineer',
#        'electrical engineer &amp;data analyst',
#        'Senior front-end web developer', 'HR specialist',
#        'Software Development Team Lead', 'BI Analyst',
#        'Business Analytics Nanodegrees', 'IT engineer', 'RF Manager',
#        'Administrative', 'Service General Manager at biomedical company',
#        'Software engineer', 'Sw eng', 'Chemist', 'Data Scientist',
#        'product manager', 'Content marketing', 'IT Specialist',
#        'Freelance Translator', 'A.I. Specialist', 'banker', 'A student',
#        'Data scientist', 'Civil Engineer', 'marketing and sales manager',
#        'web designer', 'Marketer', 'Web Developer.',
#        'Digital Marketing Professional', 'front-end dev',
#        'digital marketer', 'SAN &amp; Storage admin', 'Network Architect',
#        'web developer', 'Customer service agent', 'Graphic designer',
#        'Business Development', 'Chemical Engneer',
#        'Machine Learning Nanodegree student', 'Artist', 'Mr', 'Manager',
#        'Datascience student', 'Marketing manager',
#        'digital marketing profissinal', 'Mechanical Engineer',
#        'civilengineer', 'Planning Support officer',
#        'Machine learning engineer', 'Software Engineer Student',
#        'LMS Administrator', 'Math Teacher', 'Biology student',
#        'front-end web developer', 'CTO', 'Branch Manager',
#        'Ad Product Manager', 'Back-end, Android Engineer',
#        'Marketing Strategist', 'Digital Marketer', 'Architect',
#        'Marketing Specialist', 'Teacher', 'Front end developer',
#        'Credit Modeller / Data Scientist', 'social media marketer',
#        'Learner', 'Marketing', 'Co-op Data Engineer',
#        'Digital Marketing Manager @ REMAX Avalon', 'System engineer',
#        'R&amp;D Project Manager', 'Engineering Student', 'Engineer',
#        'E-marketing supervisor', 'Android Developer', 'Consultant',
#        'Data Analysis Nano-degree from udacity', 'Hotel Manager',
#        'Telecommunications Engineer', 'full stack web dev',
#        'Customer Solutions Database Specialist', 'Business Analyst',
#        'Senior technical analyst', 'Product Development Engineer',
#        'Useless', 'Actuary', 'Udacity student', 'Data Science',
#        'Mkt Manager', 'Android developer', 'Translator',
#        'Senior Data Scientist', 'Wed Developer', 'Insight Analyst',
#        'Marketing Manager ', 'Mobile Developer', 'Graduate Student',
#        'Genius', 'Technical Writer', 'Aspiring Developer', 'Director',
#        'Sales Engineer', 'Sales', 'UX design intern', 'Ux/Ui designe',
#        'UX Design Career Track', 'Data Science Student',
#        'Machine Learning Engineer', 'UI/UX Designer',
#        'Analytics Engineer', 'Financial Analyst', 'UI/UX Specialist',
#        'Software Engineering Student',
#        'Data Analytics Fellowship Student', 'New Business Analyst',
#        'UX/UI Student', 'BI Engineer', 'Business Owner', 'Patient Access',
#        'Senior Data Engineer', 'Software Engineering Career Track',
#        'Management and Program Analyst', 'Graduate',
#        'Business Intelligence Analyst',
#        'Full-Stack Software Engineering Graduate',
#        'Associate Product Designer', 'Personal Banker',
#        'Compliance Analyst', 'Software Engineer I',
#        'SpringBoard Data Analytics', 'Content Designer',
#        'UX Designer/Researcher', 'Associate Technical Consultant',
#        'Data Analytics Career Track', 'Data Science Career Track',
#        'Supply Chain Analyst', 'Technical Product Manager',
#        'UI/UX Design Career Track', 'Associate Marketing Specialist',
#        'Freelance UX Designer', 'Data Analyst Career Track',
#        'Senior Web Designer', 'AML Anlayst', 'N/A', 'Case Study Analyst',
#        'Junior UX researcher', 'Data analytics', 'Ops Manager',
#        'UX Specialist', 'Cloud', 'Data Anayst',
#        'Data Analytics Certification Candidate', 'Data Analytics Track',
#        'User Experience Designer', 'Creative Lead',
#        'Design Development Engineer',
#        'UX UI Design Career Track at Springboard', 'UIUX Designer',
#        'UI / UX Designer', 'Data Operations Lead', 'Computer Engineer',
#        'Product / User Experience Designer', 'Freelance Designer',
#        'Electronics Engineer', 'Datascience Career track',
#        'Data Analytics Career Track Certification', 'Full Stack Engineer',
#        'Machine Learning System Architect', 'Student - Data Analytics',
#        'UX CAREER TRACK',
#        'Billing Account Manager / Invoice Dispute AnalystDispute Analyst',
#        'Website Manager', 'Ph.D. student', 'Information Design Manager',
#        'Programming Strategist', 'Sr. UX Writer', 'data analyst',
#        'UX designer/consultant', 'Data Scientist and Project Manager',
#        'UX Research/Designer', 'UX Design', 'Springboard Alumni',
#        'Art Teacher', 'Digital Designer', 'Creative Director',
#        'User Experience Researcher', 'Photographer', 'Senior Manager',
#        'Bioinformatics Scientist', 'Software',
#        'Machine learning Engineer', 'Looking for work',
#        'Director of Digital Media', 'Data Science Intern', 'Link Builder',
#        'Videographer', 'caseworker', 'Structural Engineer',
#        'Manager,  Information Delivery', 'Growth Marketer', 'Scientist',
#        'Senior data scientist', 'Junior Data Scientist',
#        'Data Analyst, Applied Statistician', 'Estimator', 'Outreach Lead',
#        'Chief Digital Officer', 'Business Data Analyst',
#        'VP of Technology', 'Art Director', 'data scientist',
#        'Media Trader', 'Corporate IT Support Engineer',
#        'Network Engineer/UX Architect', 'Senior Packaging Designer',
#        'Visual &amp; UX Designer', 'Director of Marketing', 'Researcher',
#        'Sr UX Consultant', 'Data Analytics Manager',
#        'Senior Data Management and Analytics ', 'marketing associate',
#        'UX Desginer', 'Interactive Visual Designer', 'Digital Producer',
#        'Pricing Analyst', 'IT Service Desk', 'Professor', 'UX design',
#        'Economist', 'Systems Analyst', 'Security Analytics Engineer',
#        'UX Engineer', 'Creative Area Manager', 'Cognitive Analyst',
#        'Customer Service Manager', 'ux designer', 'Operations in Tech',
#        'Healthcare Analyst II', 'Digital Marketing Specialist',
#        'UX Designer ', 'Data Entry', 'HIM', 'Sr/ Software Engineer',
#        'Support Lead', 'Jr. Product Designer', 'Foreign Service Officer',
#        'teacher', 'User Experience Specialist', 'Info Security Analyst',
#        'Senior Actuarial Analyst', 'Illustrator and Designer',
#        'Sr Data Scientist', 'Senior Graphic Designer', 'Visual Designer',
#        'UX Business Analyst', 'Creative Product Analyst', 'President',
#        'Python Engineer - Machine Learning', 'Digital Marketing Manager',
#        'Sr.Data Analyst ', 'Sr Analyst', 'Creative Designer + Director',
#        'Data Scientist intern at Shell', 'Content Specialist',
#        'Research Scientist', 'UX/Product Designer', 'UI UX Designer',
#        'UX Design Intern', 'Chief Strategist ', 'UX Writer',
#        'Web Designer/UX Designer', 'UX / UI designer',
#        'Principal Program Manager', 'Consulting Software Engineer',
#        'Global Marketing Manager', 'Website Manager-UX Lead',
#        'Lead Designer/Creative Director', 'Web Dev Student at Practicum',
#        'Accountant', 'QA Analyst/dev in training', 'PhD student',
#        'Clinical Data Analyst', 'IT Manager', 'Marketing Data Analyst',
#        'Advanced Business Analyst',
#        'Ph.D. Student Economist | Trader | Quant', 'University Student',
#        'Product Delivery Manager', 'Content Marketing Manager',
#        'Operations Research Analyst',
#        'Senior Scrum Master / Release Train Engineer',
#        'Senior Consultant', 'marketer', 'UX Product Designer',
#        'Senior Business Intelligence Analyst',
#        'Sr. Product Marketing Manager',
#        'Freelance Graphic &amp; Web Designer', 'Agility Lead',
#        'UX / UI Freelancer',
#        'Associate Director, International Admissions and Marketing',
#        'Associate Product Manager', 'Ecommerce Manager', 'VP',
#        'Senior Brand Manager', 'Founder of Mimoolah',
#        'Freelance Digital Marketing and Entrepreneur', 'UX Manager',
#        'Senior Sales Associate', 'Head of Digital Marketing',
#        'Product Design &amp; Developmet', 'Sr. Business Analyst',
#        'Digital Marketing Strategist ', 'Service Support Coach',
#        'Program Associate ', 'Strategist ',
#        'Senior Brand Manager Shopper Marketing',
#        'Events and Marketing Coordinator ', 'Content Creator',
#        'Marketing Manageer', 'Brand Strategist',
#        'Manager, Project Delivery', 'Manager at Motive Health',
#        'Marketing Assistant', 'Fundraiser', 'Journalist', 'HR Manager',
#        'CEO', 'Regional Marketing Manager',
#        'Sessional Instructor at Emily Carr University of Art and Design',
#        'Marketing Manager', 'Marketing Specialist ',
#        'Electrical Engineer', 'Product/Project Manager', 'Mineralogist',
#        'Sponsorship Coordinator', 'front-end developer',
#        'Philanthropy Assistant', 'Junior UX designer',
#        'Founder, Director of Operations', 'Marketing Coordinator',
#        'Project Manager, Developer', 'COO', 'Program Manager, Learning',
#        'Social Media Coordinator', 'Accounts Manager ',
#        'Business Development Manager', 'Office Manager',
#        'Web Development Intern', 'Event Manager/Actress',
#        'Software Test Associate', 'Editor'], dtype=object)

# %%
from sqlalchemy import create_engine

# %%
host="localhost"
port=3306
dbname="project"
user="root"
password="Popmaster17+"

# %%
cnx = create_engine(f"mysql+mysqlconnector://{user}:{password}@{host}/{dbname}").connect()

# %%
courses.to_sql("courses", con = cnx, if_exists="replace")

# %%
cleaned_comments.to_sql("comments", con = cnx, if_exists="replace")

# %%
cleaned_locations.to_sql("locations", con = cnx, if_exists="replace")

# %%
cleaned_schools.to_sql("schools", con = cnx, if_exists="replace")

# %%
badges_for_schools.to_sql("badges_schools", con = cnx, if_exists="replace")

# %%
# Q1 
# Que aspetos a Ironhack pode melhorar relativamente às concorrentes com base nos indicadores (overall, jobsupport, curriculum) 
# – corr dos indicadores com o overallscore média de cada indicador mostra 
# que a Ironhack perde nos indicadores ‘overall’ e ‘curriculum’, 
# entretanto é a escola mais forte em ‘jubsupport’Empregabilidade do curso – como o jobsupport mudou ao longo tempo

#Q2 
#Empregabilidade do curso – como o jobsupport mudou ao longo tempo

#Q3
# -Como as pessoas da área avaliam o curso (não alumni e tenha o job title)

# %%
query1 = pd.read_sql_query("""select AVG(overallScore), schools_id
from (select * from project.comments
   where program = "DA") sub
   group by schools_id
   order by AVG(overallScore) asc;
""", cnx)

# %%
query1
# Out:
#    AVG(overallScore)  schools_id
# 0           4.486957       10571
# 1           4.511905       10828
# 2           4.560706       11035
# 3           4.614894       11118
# 4           4.779545       11225

# %%
distribution_ironhack = pd.read_sql_query("""select overallScore, school from (select * from project.comments where program = "DA") sub
where schools_id = 10828;""", cnx)

distribution_udacity = pd.read_sql_query("""select overallScore, school from (select * from project.comments where program = "DA") sub
where schools_id = 11118;""", cnx)

distribution_springboard = pd.read_sql_query("""select overallScore, school from (select * from project.comments where program = "DA") sub
where schools_id = 11035;""", cnx)

distribution_practicum = pd.read_sql_query("""select overallScore, school from (select * from project.comments where program = "DA") sub
where schools_id = 11225;""", cnx)

distribution_brainstation = pd.read_sql_query("""select overallScore, school from (select * from project.comments where program = "DA") sub
where schools_id = 10571;""", cnx)

# %%
scores = ["E","D","C","B","A","A+"]

distribution_ironhack["Ranking"] = pd.cut(distribution_ironhack["overallScore"], bins=[0,0.9,1.9,2.9,3.9,4.6,5], labels= scores)
(distribution_ironhack["Ranking"].groupby(distribution_ironhack["Ranking"]).count() / distribution_ironhack["Ranking"].count()) * 100

# %%
distribution_udacity["Ranking"] = pd.cut(distribution_udacity["overallScore"], bins=[0,0.9,1.9,2.9,3.9,4.6,5], labels= scores)
(distribution_udacity["Ranking"].groupby(distribution_udacity["Ranking"]).count() / distribution_udacity["Ranking"].count()) * 100

# %%
distribution_springboard["Ranking"] = pd.cut(distribution_springboard["overallScore"], bins=[0,0.9,1.9,2.9,3.9,4.6,5], labels= scores)
(distribution_springboard["Ranking"].groupby(distribution_springboard["Ranking"]).count() / distribution_springboard["Ranking"].count()) * 100

# %%
distribution_brainstation["Ranking"] = pd.cut(distribution_brainstation["overallScore"], bins=[0,0.9,1.9,2.9,3.9,4.6,5], labels= scores)
(distribution_brainstation["Ranking"].groupby(distribution_brainstation["Ranking"]).count() / distribution_brainstation["Ranking"].count()) * 100

# %%
distribution_practicum["Ranking"] = pd.cut(distribution_practicum["overallScore"], bins=[0,0.9,1.9,2.9,3.9,4.6,5], labels= scores)
(distribution_practicum["Ranking"].groupby(distribution_practicum["Ranking"]).count() / distribution_practicum["Ranking"].count()) * 100

# %%
query2 = pd.read_sql_query("""select AVG(overall), schools_id
from (select * from project.comments
   where program = "DA") sub
   group by schools_id
   order by AVG(overall) asc;
""", cnx)

# %%
query2
# Out:
#    AVG(overall)  schools_id
# 0      4.595238       10828
# 1      4.671082       11035
# 2      4.717391       10571
# 3      4.723404       11118
# 4      4.886364       11225

# %%
scores2 = ["F","D","C","B","A"]

# %%
distribution_ironhack4 = pd.read_sql_query("""select overall, school from (select * from project.comments where program = "DA") sub
where schools_id = 10828;""", cnx)

distribution_udacity4 = pd.read_sql_query("""select overall, school from (select * from project.comments where program = "DA") sub
where schools_id = 11118;""", cnx)

distribution_springboard4 = pd.read_sql_query("""select overall, school from (select * from project.comments where program = "DA") sub
where schools_id = 11035;""", cnx)

distribution_practicum4 = pd.read_sql_query("""select overall, school from (select * from project.comments where program = "DA") sub
where schools_id = 11225;""", cnx)

distribution_brainstation4 = pd.read_sql_query("""select overall, school from (select * from project.comments where program = "DA") sub
where schools_id = 10571;""", cnx)

# %%
distribution_ironhack4["Ranking overall"] = pd.cut(distribution_ironhack4["overall"], bins=[0,1,2,3,4,5], labels= scores2)
(distribution_ironhack4["Ranking overall"].groupby(distribution_ironhack4["Ranking overall"]).count() / distribution_ironhack4["Ranking overall"].count()) * 100

# %%
distribution_udacity4["Ranking overall"] = pd.cut(distribution_udacity4["overall"], bins=[0,1,2,3,4,5], labels= scores2)
(distribution_udacity4["Ranking overall"].groupby(distribution_udacity4["Ranking overall"]).count() / distribution_udacity4["Ranking overall"].count()) * 100

# %%
distribution_springboard4["Ranking overall"] = pd.cut(distribution_springboard4["overall"], bins=[0,1,2,3,4,5], labels= scores2)
(distribution_springboard4["Ranking overall"].groupby(distribution_springboard4["Ranking overall"]).count() / distribution_springboard4["Ranking overall"].count()) * 100

# %%
distribution_brainstation4["Ranking overall"] = pd.cut(distribution_brainstation4["overall"], bins=[0,1,2,3,4,5], labels= scores2)
(distribution_brainstation4["Ranking overall"].groupby(distribution_brainstation4["Ranking overall"]).count() / distribution_brainstation4["Ranking overall"].count()) * 100

# %%
distribution_practicum4["Ranking overall"] = pd.cut(distribution_practicum4["overall"], bins=[0,1,2,3,4,5], labels= scores2)
(distribution_practicum4["Ranking overall"].groupby(distribution_practicum4["Ranking overall"]).count() / distribution_practicum4["Ranking overall"].count()) * 100

# %%
query3 = pd.read_sql_query("""select AVG(curriculum), schools_id
from (select * from project.comments
   where program = "DA") sub
   group by schools_id
   order by AVG(curriculum) asc;
""", cnx)

# %%
query3

# %%
distribution_ironhack2 = pd.read_sql_query("""select curriculum, school from (select * from project.comments where program = "DA") sub
where schools_id = 10828;""", cnx)

distribution_udacity2 = pd.read_sql_query("""select curriculum, school from (select * from project.comments where program = "DA") sub
where schools_id = 11118;""", cnx)

distribution_springboard2 = pd.read_sql_query("""select curriculum, school from (select * from project.comments where program = "DA") sub
where schools_id = 11035;""", cnx)

distribution_practicum2 = pd.read_sql_query("""select curriculum, school from (select * from project.comments where program = "DA") sub
where schools_id = 11225;""", cnx)

distribution_brainstation2 = pd.read_sql_query("""select curriculum, school from (select * from project.comments where program = "DA") sub
where schools_id = 10571;""", cnx)

# %%
distribution_ironhack2["Ranking Curriculum"] = pd.cut(distribution_ironhack2["curriculum"], bins=[0,1,2,3,4,5], labels= scores2)
(distribution_ironhack2["Ranking Curriculum"].groupby(distribution_ironhack2["Ranking Curriculum"]).count() / distribution_ironhack2["Ranking Curriculum"].count()) * 100

# %%
distribution_udacity2["Ranking Curriculum"] = pd.cut(distribution_udacity2["curriculum"], bins=[0.9,1.9,2.9,3.9,4.6,5], labels= scores2)
(distribution_udacity2["Ranking Curriculum"].groupby(distribution_udacity2["Ranking Curriculum"]).count() / distribution_udacity2["Ranking Curriculum"].count()) * 100

# %%
distribution_springboard2["Ranking curriculum"] = pd.cut(distribution_springboard2["curriculum"], bins=[0.9,1.9,2.9,3.9,4.6,5], labels= scores2)
(distribution_springboard2["Ranking curriculum"].groupby(distribution_springboard2["Ranking curriculum"]).count() / distribution_springboard2["Ranking curriculum"].count()) * 100

# %%
distribution_brainstation2["Ranking curriculum"] = pd.cut(distribution_brainstation2["curriculum"], bins=[0.9,1.9,2.9,3.9,4.6,5], labels= scores2)
(distribution_brainstation2["Ranking curriculum"].groupby(distribution_brainstation2["Ranking curriculum"]).count() / distribution_brainstation2["Ranking curriculum"].count()) * 100

# %%
distribution_practicum2["Ranking curriculum"] = pd.cut(distribution_practicum2["curriculum"], bins=[0.9,1.9,2.9,3.9,4.6,5], labels= scores2)
(distribution_practicum2["Ranking curriculum"].groupby(distribution_practicum2["Ranking curriculum"]).count() / distribution_practicum2["Ranking curriculum"].count()) * 100

# %%
# Out:
#    AVG(curriculum)  schools_id
# 0         4.500000       10828
# 1         4.505519       11035
# 2         4.630435       10571
# 3         4.765957       11118
# 4         4.795455       11225

# %%
query4 = pd.read_sql_query("""select AVG(jobSupport), schools_id
from (select * from project.comments
   where program = "DA") sub
   group by schools_id
   order by AVG(jobSupport) asc;
""", cnx)

# %%
query4
# Out:
#    AVG(jobSupport)  schools_id
# 0         3.586957       10571
# 1         4.125828       11035
# 2         4.148936       11118
# 3         4.181818       11225
# 4         4.428571       10828

# %%
distribution_ironhack3 = pd.read_sql_query("""select jobSupport, school from (select * from project.comments where program = "DA") sub
where schools_id = 10828;""", cnx)

distribution_udacity3 = pd.read_sql_query("""select jobSupport, school from (select * from project.comments where program = "DA") sub
where schools_id = 11118;""", cnx)

distribution_springboard3 = pd.read_sql_query("""select jobSupport, school from (select * from project.comments where program = "DA") sub
where schools_id = 11035;""", cnx)

distribution_practicum3 = pd.read_sql_query("""select jobSupport, school from (select * from project.comments where program = "DA") sub
where schools_id = 11225;""", cnx)

distribution_brainstation3 = pd.read_sql_query("""select jobSupport, school from (select * from project.comments where program = "DA") sub
where schools_id = 10571;""", cnx)

# %%
distribution_ironhack3["Ranking jobSupport"] = pd.cut(distribution_ironhack3["jobSupport"], bins=[0,1,2,3,4,5], labels= scores2)
(distribution_ironhack3["Ranking jobSupport"].groupby(distribution_ironhack3["Ranking jobSupport"]).count() / distribution_ironhack3["Ranking jobSupport"].count()) * 100

# %%
distribution_udacity3["Ranking jobSupport"] = pd.cut(distribution_udacity3["jobSupport"], bins=[0,1,2,3,4,5], labels= scores2)
(distribution_udacity3["Ranking jobSupport"].groupby(distribution_udacity3["Ranking jobSupport"]).count() / distribution_udacity3["Ranking jobSupport"].count()) * 100

# %%
distribution_springboard3["Ranking jobSupport"] = pd.cut(distribution_springboard3["jobSupport"], bins=[0,1,2,3,4,5], labels= scores2)
(distribution_springboard3["Ranking jobSupport"].groupby(distribution_springboard3["Ranking jobSupport"]).count() / distribution_springboard3["Ranking jobSupport"].count()) * 100

# %%
distribution_brainstation3["Ranking jobSupport"] = pd.cut(distribution_brainstation3["jobSupport"], bins=[0,1,2,3,4,5], labels= scores2)
(distribution_brainstation3["Ranking jobSupport"].groupby(distribution_brainstation3["Ranking jobSupport"]).count() / distribution_brainstation3["Ranking jobSupport"].count()) * 100

# %%
distribution_practicum3["Ranking jobSupport"] = pd.cut(distribution_practicum3["jobSupport"], bins=[0,1,2,3,4,5], labels= scores2)
(distribution_practicum3["Ranking jobSupport"].groupby(distribution_practicum3["Ranking jobSupport"]).count() / distribution_practicum3["Ranking jobSupport"].count()) * 100

# %%
query_webdev1 = pd.read_sql_query("""select AVG(overallScore) as "Overall Score", school as "School", count(overallScore)
as "Total number of surveys"
from (select * from project.comments
   where program LIKE "%Web%") sub
   group by schools_id
   order by AVG(overallScore) asc;
""", cnx)

# %%
query_webdev1

# %%
query_webdev2 = pd.read_sql_query("""select AVG(overall) as "Overall", school as "School", count(overall)
as "Total number of surveys"
from (select * from project.comments
   where program LIKE "%Web%") sub
   group by schools_id
   order by AVG(overall) asc;
""", cnx)

# %%
query_webdev2

# %%
query_webdev3 = pd.read_sql_query("""select AVG(curriculum) as "Curriculum", school as "School", count(curriculum)
as "Total number of surveys"
from (select * from project.comments
   where program LIKE "%Web%") sub
   group by schools_id
   order by AVG(curriculum) asc;
""", cnx)

# %%
query_webdev3

# %%
query_webdev4 = pd.read_sql_query("""select AVG(jobSupport) as "Employability", school as "School", count(jobSupport)
as "Total number of surveys"
from (select * from project.comments
   where program LIKE "%Web%") sub
   group by schools_id
   order by AVG(jobSupport) asc;
""", cnx)

# %%
query_webdev4

# %%
#Q2 # Count total surveys vs count(jobsupport)

query_q2 = pd.read_sql_query("""select AVG(jobSupport), graduatingYear, count(jobSupport)
from project.comments
where schools_id = 10828
group by graduatingYear
order by graduatingYear asc;""", cnx)

# %%
query_q2

# %%
'Junior Data Analyst', 'Data Analyst' 'Data Analytics' 'Data  analyst' 'Data Analyst Jr' 'Data Analytics Student' 
'Junior data analyst' 'Finance Analyst' 'Data analyst'  'Engenheira de dados' 'Data Engineer'
'Data Science and Advanced Analytics Manager' 'Web Content Analyst' 'Digital Analyst' 'Programmer Analyst'
'IB Analyst' 'Digital Analyst' 'electrical engineer &amp;data analyst' 'Business Analytics Nanodegrees'

# %%
#Q3 
query_q3 = pd.read_sql_query("""select AVG(overallScore), schools_id, count(overallScore)
from (select * from project.comments where isAlumni = 0) sub
where jobTitle like "%Data%"
	or jobTitle like "%data%"
	or jobTitle like "%Analyst%"
	or jobTitle like "%analyst%"
    or jobTitle like "%analytics%"
	or jobTitle like "%Analytics%"
	or jobTitle like "%dados%"
group by schools_id
order by AVG(overallScore) asc;""", cnx)

# %%
query_q3
